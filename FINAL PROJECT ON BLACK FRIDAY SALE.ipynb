# %%
# To Find The Current working Directory
import os
os.getcwd()
# Out:
# 'C:\\Users\\DELL\\Desktop\\Datasets'

# %%
# To change current working Directory
os.chdir("C:/Users/DELL/Desktop/Datasets")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\DELL\\Desktop\\Datasets'

# %%
# Importing Data to the python Environment
import numpy as np
import pandas as pd
data1=pd.read_csv("BlackFriday1.csv")

# %%
data1
# Out:
#         User_ID Product_ID Gender  Age  Occupation City_Category  \
# 0       1000001  P00069042      F   17          10             A
# 1       1000001  P00248942      F   17          10             A
# 2       1000001  P00087842      F   17          10             A
# 3       1000001  P00085442      F   17          10             A
# 4       1000002  P00285442      M   19          16             C
# 5       1000003  P00193542      M   18          15             A
# 6       1000004  P00184942      M   23           7             B
# 7       1000004  P00346142      M   24           7             B
# 8       1000004   P0097242      M   25           7             B
# 9       1000005  P00274942      M   26          20             A
# 10      1000005  P00251242      M   27          20             A
# 11      1000005  P00014542      M   28          20             A
# 12      1000005  P00031342      M   29          20             A
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537566 entries, 0 to 537565
# Data columns (total 11 columns):
# User_ID                       537566 non-null int64
# Product_ID                    537566 non-null object
# Gender                        537566 non-null object
# Age                           537566 non-null int64
# Occupation                    537566 non-null int64
# City_Category                 537566 non-null object
# Stay_In_Current_City_Years    537566 non-null object
# Product_Category_1            537566 non-null int64
# Product_Category_2            370581 non-null float64
# Product_Category_3            164277 non-null float64
# Purchase                      537566 non-null int64
# dtypes: float64(2), int64(5), object(4)
# memory usage: 45.1+ MB

# %%
data1.head()
# Out:
#    User_ID Product_ID Gender  Age  Occupation City_Category  \
# 0  1000001  P00069042      F   17          10             A
# 1  1000001  P00248942      F   17          10             A
# 2  1000001  P00087842      F   17          10             A
# 3  1000001  P00085442      F   17          10             A
# 4  1000002  P00285442      M   19          16             C
#
#   Stay_In_Current_City_Years  Product_Category_1  Product_Category_2  \
# 0                          2                   3                 NaN
# 1                          2                   1                 6.0
# 2                          2                  12                 NaN
# 3                          2                  12                14.0
# 4                         4+                   8                 NaN
#
#    Product_Category_3  Purchase
# 0                 NaN      8370
# 1                14.0     15200
# 2                 NaN      1422
# 3                 NaN      1057
# ...

# %%
data1.tail()
# Out:
#         User_ID Product_ID Gender  Age  Occupation City_Category  \
# 537561  1004737  P00193542      M   66          16             C
# 537562  1004737  P00111142      M   66          16             C
# 537563  1004737  P00345942      M   66          16             C
# 537564  1004737  P00285842      M   66          16             C
# 537565  1004737  P00118242      M   66          16             C
#
#        Stay_In_Current_City_Years  Product_Category_1  Product_Category_2  \
# 537561                          1                   1                 2.0
# 537562                          1                   1                15.0
# 537563                          1                   8                15.0
# 537564                          1                   5                 NaN
# 537565                          1                   5                 8.0
#
#         Product_Category_3  Purchase
# 537561                 NaN     11664
# 537562                16.0     19196
# ...

# %%
#drop unwanted columns(id's)
df1=data1.drop(columns=['User_ID','Product_ID'])

# %%
df1
# Out:
#        Gender  Age  Occupation City_Category Stay_In_Current_City_Years  \
# 0           F   17          10             A                          2
# 1           F   17          10             A                          2
# 2           F   17          10             A                          2
# 3           F   17          10             A                          2
# 4           M   19          16             C                         4+
# 5           M   18          15             A                          3
# 6           M   23           7             B                          2
# 7           M   24           7             B                          2
# 8           M   25           7             B                          2
# 9           M   26          20             A                          1
# 10          M   27          20             A                          1
# 11          M   28          20             A                          1
# ...

# %%
# it sums up the empty or null boxes
#axis=0 for columns
#axis=1 for rows
df1.apply(lambda x:sum(x.isnull()),axis=0)
# Out:
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Product_Category_1                 0
# Product_Category_2            166985
# Product_Category_3            373289
# Purchase                           0
# dtype: int64

# %%
# Replacing Catogarical data with Numerical Data
df1['Gender'].replace(['F','M'],[0,1],inplace=True)
df1['City_Category'].replace(['A','B','C'],[1,2,3],inplace=True)

# %%
df1
# Out:
#         Gender  Age  Occupation  City_Category Stay_In_Current_City_Years  \
# 0            0   17          10              1                          2
# 1            0   17          10              1                          2
# 2            0   17          10              1                          2
# 3            0   17          10              1                          2
# 4            1   19          16              3                         4+
# 5            1   18          15              1                          3
# 6            1   23           7              2                          2
# 7            1   24           7              2                          2
# 8            1   25           7              2                          2
# 9            1   26          20              1                          1
# 10           1   27          20              1                          1
# 11           1   28          20              1                          1
# ...

# %%
df1['Stay_In_Current_City_Years']=(df1['Stay_In_Current_City_Years'].str.strip('+').astype('int'))

# %%
df1
# Out:
#         Gender  Age  Occupation  City_Category  Stay_In_Current_City_Years  \
# 0            0   17          10              1                           2
# 1            0   17          10              1                           2
# 2            0   17          10              1                           2
# 3            0   17          10              1                           2
# 4            1   19          16              3                           4
# 5            1   18          15              1                           3
# 6            1   23           7              2                           2
# 7            1   24           7              2                           2
# 8            1   25           7              2                           2
# 9            1   26          20              1                           1
# 10           1   27          20              1                           1
# ...

# %%
df1.cov()
# Out:
#                                 Gender         Age  Occupation  City_Category  \
# Gender                        0.185443    0.032374    0.329557      -0.001349
# Age                           0.032374  249.665887    0.256150       0.055391
# Occupation                    0.329557    0.256150   42.564593       0.167454
# City_Category                -0.001349    0.055391    0.167454       0.577024
# Stay_In_Current_City_Years    0.008551    0.043738    0.262580       0.019531
# Product_Category_1           -0.073747    0.038098   -0.198609      -0.078194
# Product_Category_2           -0.040212    0.054259   -0.000894      -0.046861
# Product_Category_3            0.048912   -0.265554    0.359588      -0.008337
# Purchase                    128.888707   72.111353  685.842408     259.194640
#
#                             Stay_In_Current_City_Years  Product_Category_1  \
# Gender                                        0.008551           -0.073747
# ...

# %%
df1.corr()
# Out:
#                               Gender       Age  Occupation  City_Category  \
# Gender                      1.000000  0.004758    0.117301      -0.004125
# Age                         0.004758  1.000000    0.002485       0.004615
# Occupation                  0.117301  0.002485    1.000000       0.033789
# City_Category              -0.004125  0.004615    0.033789       1.000000
# Stay_In_Current_City_Years  0.015396  0.002146    0.031204       0.019934
# Product_Category_1         -0.045659  0.000643   -0.008116      -0.027445
# Product_Category_2         -0.018444  0.000675   -0.000027      -0.012120
# Product_Category_3          0.028408 -0.004087    0.013441      -0.002661
# Purchase                    0.060089  0.000916    0.021105       0.068503
#
#                             Stay_In_Current_City_Years  Product_Category_1  \
# Gender                                        0.015396           -0.045659
# Age                                           0.002146            0.000643
# ...

# %%
df1.describe()
# Out:
#               Gender            Age     Occupation  City_Category  \
# count  537566.000000  537566.000000  537566.000000  537566.000000
# mean        0.754082      41.625354       8.082779       2.040574
# std         0.430630      15.800819       6.524155       0.759621
# min         0.000000       5.000000       0.000000       1.000000
# 25%         1.000000      29.000000       2.000000       1.000000
# 50%         1.000000      35.000000       7.000000       2.000000
# 75%         1.000000      51.000000      14.000000       3.000000
# max         1.000000      82.000000      20.000000       3.000000
#
#        Stay_In_Current_City_Years  Product_Category_1  Product_Category_2  \
# count               537566.000000       537566.000000       370581.000000
# mean                     1.859467            5.295560            9.842115
# std                      1.289832            3.750714            5.087286
# min                      0.000000            1.000000            2.000000
# ...

# %%
# seperating Predictors and Targets
features=df1.iloc[:,:-1]

# %%
labels=df1.iloc[:,-1]

# %%
features
# Out:
#         Gender  Age  Occupation  City_Category  Stay_In_Current_City_Years  \
# 0            0   17          10              1                           2
# 1            0   17          10              1                           2
# 2            0   17          10              1                           2
# 3            0   17          10              1                           2
# 4            1   19          16              3                           4
# 5            1   18          15              1                           3
# 6            1   23           7              2                           2
# 7            1   24           7              2                           2
# 8            1   25           7              2                           2
# 9            1   26          20              1                           1
# 10           1   27          20              1                           1
# ...

# %%
labels
# Out:
# 0          8370
# 1         15200
# 2          1422
# 3          1057
# 4          7969
# 5         15227
# 6         19215
# 7         15854
# 8         15686
# 9          7871
# 10         5254
# 11         3957
# 12         6073
# 13        15665
# 14         5378
# 15         2079
# 16        13055
# 17         8851
# 18        11788
# 19        19614
# 20         8584
# 21         9872
# 22         9743
# 23         5982
# 24        11927
# 25        16662
# 26         5887
# 27         6973
# 28         5391
# 29        16352
#           ...
# 537536    11543
# 537537    20924
# 537538    13082
# 537539    11658
# 537540     6863
# 537541    16415
# 537542    18526
# 537543     7099
# 537544      578
# 537545     2183
# 537546    12724
# 537547     7796
# 537548     7770
# 537549     5940
# 537550     7834
# 537551    11508
# 537552     6074
# 537553     7084
# 537554     7934
# 537555     5350
# 537556     1994
# 537557     5930
# 537558     7042
# 537559    15491
# ...

# %%
#replaces all numerical missing values at once
from sklearn.preprocessing import Imputer
imputer=Imputer(missing_values='NaN',strategy='mean',axis=0)
# Out:
# C:\Users\DELL\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:58: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
imputer.fit(features.iloc[:,[6,7]])
features.iloc[:,[6,7]]=imputer.fit_transform(features.iloc[:,[6,7]])

# %%
df1=pd.DataFrame(features)

# %%
features
# Out:
#         Gender  Age  Occupation  City_Category  Stay_In_Current_City_Years  \
# 0            0   17          10              1                           2
# 1            0   17          10              1                           2
# 2            0   17          10              1                           2
# 3            0   17          10              1                           2
# 4            1   19          16              3                           4
# 5            1   18          15              1                           3
# 6            1   23           7              2                           2
# 7            1   24           7              2                           2
# 8            1   25           7              2                           2
# 9            1   26          20              1                           1
# 10           1   27          20              1                           1
# ...

# %%
df1.apply(lambda x:sum(x.isnull()),axis=0)
# Out:
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Product_Category_1            0
# Product_Category_2            0
# Product_Category_3            0
# dtype: int64

# %%
df1.columns
# Out:
# Index(['Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3'],
#       dtype='object')

# %%
x=features
y=labels

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(features.iloc[:,5],y,'o')
plt.xlabel("y")
plt.ylabel("Product_Category_1")
# Out:
# Text(0, 0.5, 'Product_Category_1')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(features.iloc[:,2],y,'o')
plt.xlabel("y")
plt.ylabel("Occupation")
# Out:
# Text(0, 0.5, 'Occupation')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(features.iloc[:,6],y,'o')
plt.xlabel("y")
plt.ylabel("Product_Category_2")
# Out:
# Text(0, 0.5, 'Product_Category_2')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(features.iloc[:,6],y,'o')
plt.xlabel("y")
plt.ylabel("Product_Category_3")
# Out:
# Text(0, 0.5, 'Product_Category_3')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(features.iloc[:,0],y,'o')
plt.xlabel("y")
plt.ylabel("Gender")
# Out:
# Text(0, 0.5, 'Gender')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(features.iloc[:,1],y,'o')
plt.xlabel("y")
plt.ylabel("Age")
# Out:
# Text(0, 0.5, 'Age')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(features.iloc[:,3],y,'o')
plt.xlabel("y")
plt.ylabel("City_Category")
# Out:
# Text(0, 0.5, 'City_Category')

# %% [markdown]
# # Box plots

# %%
df1.boxplot(column='Gender')

# %%
df1.boxplot(column='Age')

# %%
df1.boxplot(column='Occupation')

# %%
df1.boxplot(column='City_Category')

# %%
df1.boxplot(column='Stay_In_Current_City_Years')

# %%
df1.boxplot(column='Product_Category_1')

# %%
df1.boxplot(column='Product_Category_2')

# %%
df1.boxplot(column='Product_Category_3')

# %%
import statsmodels.api as sm
model=sm.OLS(y,x).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               Purchase   R-squared:                       0.786
# Model:                            OLS   Adj. R-squared:                  0.786
# Method:                 Least Squares   F-statistic:                 2.466e+05
# Date:                Thu, 30 May 2019   Prob (F-statistic):               0.00
# Time:                        17:55:36   Log-Likelihood:            -5.3300e+06
# No. Observations:              537566   AIC:                         1.066e+07
# Df Residuals:                  537558   BIC:                         1.066e+07
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# # Heat maps

# %%
corr=df1.corr()
sns.heatmap(corr,xticklabels=corr.columns,yticklabels=corr.columns)

# %% [markdown]
# # Training and Testing the data

# %%
from sklearn import model_selection,neighbors
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
x_train
# Out:
#         Gender  Age  Occupation  City_Category  Stay_In_Current_City_Years  \
# 136784       0   31          16              3                           1
# 176201       0   33           6              2                           3
# 438394       1   26           7              3                           3
# 242303       1   29           7              1                           2
# 253918       1   29           0              3                           3
# 488076       1   35          15              1                           1
# 356467       0   82           7              2                           1
# 74572        1   67           2              1                           3
# 338207       1   64           3              2                           2
# 307873       1   55          12              3                           1
# 253955       0   29           0              1                           0
# ...

# %%
y_train
# Out:
# 136784     7922
# 176201     9815
# 438394    11797
# 242303     1532
# 253918    12081
# 488076     2104
# 356467     5988
# 74572      5326
# 338207    19618
# 307873    15459
# 253955    18686
# 440313     8108
# 367298    11640
# 118993     6166
# 383000      926
# 428569     8805
# 96945     15548
# 215531    10607
# 115367     4089
# 121108     7041
# 75059      5189
# 89565     15168
# 321074     5446
# 141043    15772
# 487921     9953
# 450072     8033
# 302855    11584
# 485434     3467
# 270407     8816
# 84809      7050
#           ...
# 492254     8647
# 325882     7931
# 464393    13256
# 116983     7906
# 491040     7523
# 402113     2009
# 433171     7965
# 271372     8769
# 257683     7006
# 293550     8713
# 329446     9712
# 180217     5930
# 203032    15310
# 209818     3551
# 226710     9751
# 250056     9882
# 194739     7055
# 353727    15520
# 91148     13309
# 159405     6067
# 363035     7165
# 135180     3492
# 331296     5220
# 518048     9996
# ...

# %%
x_test
# Out:
#         Gender  Age  Occupation  City_Category  Stay_In_Current_City_Years  \
# 489769       1   35          17              3                           1
# 54387        1   50          18              3                           2
# 330542       1   79          17              2                           0
# 337706       0   64           9              3                           1
# 85623        1   67           2              3                           4
# 105437       1   22          12              3                           3
# 431439       0   26           0              3                           0
# 406112       1   43           1              2                           1
# 395275       0   43           1              2                           4
# 174064       0   33          20              2                           3
# 475590       1   35           4              2                           0
# ...

# %%
y_test
# Out:
# 489769     7801
# 54387     15337
# 330542    15279
# 337706     3538
# 85623     17009
# 105437    21035
# 431439    13497
# 406112    16090
# 395275     7033
# 174064     8004
# 475590    23476
# 184725     4738
# 520471     8709
# 526458     5328
# 189465     5976
# 3781      10888
# 415666     8741
# 140434     4131
# 518        7193
# 449931     7855
# 11354      5849
# 316083    12043
# 432575    20602
# 381569    15776
# 281766    15386
# 118202     9911
# 411637      953
# 166030     4481
# 171738     5198
# 81609      3074
#           ...
# 31291     16620
# 266026    11849
# 529202     7135
# 409764     8025
# 131185    11042
# 493123    12862
# 135295     3520
# 21242     12038
# 308760    19560
# 151220     3556
# 336986     7116
# 161745     1504
# 224058     5902
# 77038      6996
# 197221     9708
# 227567     8239
# 115693     1031
# 49198     17198
# 444965    11370
# 419208    19055
# 342092    12605
# 359214     7675
# 73039     19478
# 241938     5436
# ...

# %%
X=x

# %%
X
# Out:
#         Gender  Age  Occupation  City_Category  Stay_In_Current_City_Years  \
# 0            0   17          10              1                           2
# 1            0   17          10              1                           2
# 2            0   17          10              1                           2
# 3            0   17          10              1                           2
# 4            1   19          16              3                           4
# 5            1   18          15              1                           3
# 6            1   23           7              2                           2
# 7            1   24           7              2                           2
# 8            1   25           7              2                           2
# 9            1   26          20              1                           1
# 10           1   27          20              1                           1
# ...

# %%
y
# Out:
# 0          8370
# 1         15200
# 2          1422
# 3          1057
# 4          7969
# 5         15227
# 6         19215
# 7         15854
# 8         15686
# 9          7871
# 10         5254
# 11         3957
# 12         6073
# 13        15665
# 14         5378
# 15         2079
# 16        13055
# 17         8851
# 18        11788
# 19        19614
# 20         8584
# 21         9872
# 22         9743
# 23         5982
# 24        11927
# 25        16662
# 26         5887
# 27         6973
# 28         5391
# 29        16352
#           ...
# 537536    11543
# 537537    20924
# 537538    13082
# 537539    11658
# 537540     6863
# 537541    16415
# 537542    18526
# 537543     7099
# 537544      578
# 537545     2183
# 537546    12724
# 537547     7796
# 537548     7770
# 537549     5940
# 537550     7834
# 537551    11508
# 537552     6074
# 537553     7084
# 537554     7934
# 537555     5350
# 537556     1994
# 537557     5930
# 537558     7042
# 537559    15491
# ...

# %%
model1=sm.OLS(y,X).fit()
predictions=model1.predict(X)

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               Purchase   R-squared:                       0.786
# Model:                            OLS   Adj. R-squared:                  0.786
# Method:                 Least Squares   F-statistic:                 2.466e+05
# Date:                Thu, 30 May 2019   Prob (F-statistic):               0.00
# Time:                        17:55:46   Log-Likelihood:            -5.3300e+06
# No. Observations:              537566   AIC:                         1.066e+07
# Df Residuals:                  537558   BIC:                         1.066e+07
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
# split data
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.4,random_state=1)

# %%
X_train
# Out:
#         Gender  Age  Occupation  City_Category  Stay_In_Current_City_Years  \
# 328831       1   79           6              2                           1
# 506882       1   33           0              2                           1
# 3261         1   42          12              1                           1
# 293564       1   45          20              3                           0
# 469873       0   26           0              2                           3
# 34556        0   23           7              1                           4
# 111727       1   23           0              2                           1
# 536885       1   66          20              2                           1
# 104345       1   22           0              1                           1
# 316301       1   55           4              2                           2
# 288998       0   45           9              1                           3
# ...

# %%
y_train
# Out:
# 328831     5372
# 506882      927
# 3261       8064
# 293564    10077
# 469873     6869
# 34556      5232
# 111727    15812
# 536885    20653
# 104345     7973
# 316301    11675
# 288998    15686
# 16252      2347
# 325653     9840
# 340141     8113
# 45673     13458
# 311047    13600
# 88212      6124
# 26123     19468
# 529192     6961
# 469850     7797
# 317823    16282
# 525913     7702
# 221052     5357
# 152165     9892
# 374463    10135
# 210972    15655
# 62752      7744
# 166757     5819
# 492011    15349
# 343855     7188
#           ...
# 369977     1777
# 117565      584
# 99335      7620
# 296022     7150
# 444256    11063
# 26103      5278
# 148209    16040
# 412649     5421
# 294103    11771
# 246322     4461
# 188317    15754
# 365212     6877
# 401660     3922
# 457611     8883
# 176485     2082
# 21758     12033
# 513300     7785
# 167302     6105
# 293372    11821
# 436973     8037
# 413825     6125
# 229520     6859
# 21440      9746
# 117583    11633
# ...

# %%
features=X_train.iloc[:,:].values

# %%
features
# Out:
# array([[ 1.        , 79.        ,  6.        , ...,  5.        ,
#          8.        , 12.66988075],
#        [ 1.        , 33.        ,  0.        , ..., 13.        ,
#         16.        , 12.66988075],
#        [ 1.        , 42.        , 12.        , ...,  8.        ,
#         15.        , 12.66988075],
#        ...,
#        [ 1.        , 26.        , 15.        , ...,  1.        ,
#          2.        , 15.        ],
#        [ 1.        , 35.        ,  5.        , ...,  5.        ,
#         11.        , 12.66988075],
#        [ 0.        , 28.        ,  4.        , ..., 11.        ,
#          9.84211549, 12.66988075]])

# %%
labels=y_train.iloc[:].values

# %%
labels
# Out:
# array([ 5372,   927,  8064, ..., 15410,  3550,  4579], dtype=int64)

# %%
X=features
y=labels

# %%
from sklearn import linear_model as lm
model=lm.LinearRegression()
results=model.fit(X,y)

# %%
predictions=model.predict(X)

# %%
accuracy=model.score(X,y)
print('Accuracy of the model:',accuracy)
# Out:
# Accuracy of the model: 0.11049644475853239

# %%
import numpy as np
from sklearn.metrics import mean_squared_error,r2_score
rmse_training=(np.sqrt(mean_squared_error(y,predictions)))#rmse_training is rrot m
r2_training=r2_score(y,predictions)

# %%
print("The model performance")
print("--------------------")
print('RMSE is {}'.format(rmse_training))
print('R2 score is {}'.format(r2_training))
print("\n")
# Out:
# The model performance
# --------------------
# RMSE is 4698.775642780211
# R2 score is 0.11049644475853238

# %%
rmse_testing=(np.sqrt(mean_squared_error(y,predictions)))#rmse_training is rrot m
r2_testing=r2_score(y,predictions)

# %%
print("The model performance")
print("--------------------")
print('RMSE is {}'.format(rmse_testing))
print('R2 score is {}'.format(r2_testing))
print("\n")
# Out:
# The model performance
# --------------------
# RMSE is 4698.775642780211
# R2 score is 0.11049644475853238
